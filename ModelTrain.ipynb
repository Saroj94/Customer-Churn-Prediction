# %% [markdown]
# <center><font size=+4 color='white'><b>Telco Customer Churn</b></font></center>

# %% [markdown]
# ## Training Tree Based Models
# - XGBoost
# - Tree Models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
##loading dataset
df=pd.read_csv('TelcoChurn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %% [markdown]
# ## Variable data types

# %%
##variable data types
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# PromptInput          object
# CustomerFeedback     object
# dtype: object

# %% [markdown]
# ## Observation
# Target variable is a categorical data type, So it is a classification problem.

# %% [markdown]
# ## Shape of the dataset

# %%
## shape
df.shape
# Out:
# (7043, 23)

# %% [markdown]
# ## Missing Values

# %%
##missing values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# PromptInput         0
# CustomerFeedback    0
# dtype: int64

# %% [markdown]
# ## Data Imbalance check

# %%
##Imbalance check
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
# High class imbalance in dataset.

# %%
## Duplicate check
df.duplicated().value_counts()
# Out:
# False    7043
# Name: count, dtype: int64

# %% [markdown]
# <center><font size=+4 color='white'><b> Univariate Analysis</b></font></center>

# %% [markdown]
# ## Required columns

# %%
df.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0              No  Month-to-month              Yes  Electronic check
#
#   MonthlyCharges TotalCharges Churn  \
# 0          29.85        29.85    No
#
#                                          PromptInput  \
# 0  Write a realistic customer feedback based on t...
#
#                                     CustomerFeedback
# 0  I have been using the DSL internet service fro...
#
# [1 rows x 23 columns]

# %%
##Required columns
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'PromptInput', 'CustomerFeedback'],
#       dtype='object')

# %%
##new columns
col=['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges','CustomerFeedback', 'Churn']
df_train=df[col]

# %%
##displaying all the columns and values
pd.set_option('display.max_columns',None)
df_train.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
## Descriptive stats for numerical feature
df_train.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
##Descriptive stats for categorical feature
df_train.describe(include='object')
# Out:
#        gender Partner Dependents PhoneService MultipleLines InternetService  \
# count    7043    7043       7043         7043          7043            7043
# unique      2       2          2            2             3               3
# top      Male      No         No          Yes            No     Fiber optic
# freq     3555    3641       4933         6361          3390            3096
#
#        OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# count            7043         7043             7043        7043        7043
# unique              3            3                3           3           3
# top                No           No               No          No          No
# freq             3498         3088             3095        3473        2810
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# count             7043            7043             7043              7043
# ...

# %%
##only categorical feature
cat_cols=[feat for feat in df_train.columns if df_train[feat].dtype=='object']
cat_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges',
#  'CustomerFeedback',
#  'Churn']

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
##checking other feature has the same issues
df_train[cat_cols].head(2)
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0  Female     Yes         No           No  No phone service             DSL
# 1    Male      No         No          Yes                No             DSL
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0              No  Month-to-month              Yes  Electronic check
# 1              No        One year               No      Mailed check
#
#   TotalCharges                                   CustomerFeedback Churn
# 0        29.85  I have been using the DSL internet service fro...    No
# 1       1889.5  I have been a customer with this company for o...    No

# %%
##checking the unique values of the categorical feature
dfc=df_train.copy()
for i in cat_cols:
    if i!='CustomerFeedback':
        print(dfc[i].value_counts())
        print('='*30,end='\n')
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# ...
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# ...
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# ...
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# ...
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
# ...
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
# ...
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
# ...
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
# ...
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
# ...
# TechSupport
# No                     3473
# Yes                    2044
# ...

# %%
#head of dataframe
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
##Alternative of type casting
dfc['TotalCharges']=pd.to_numeric(dfc['TotalCharges'], errors='coerce')

# %%
##checking null values
dfc.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# CustomerFeedback     0
# Churn                0
# dtype: int64

# %% [markdown]
# ## Missing value imputation

# %%
dfc['TotalCharges'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
##impute missing value
dfc['TotalCharges'].fillna(dfc['TotalCharges'].median(),inplace=True)

# %%
dfc.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# CustomerFeedback    0
# Churn               0
# dtype: int64

# %%
##training data
df_copy=df.copy()
train_df=df_copy.drop(columns=['customerID','PromptInput','CustomerFeedback'])
train_df['TotalCharges']=train_df['TotalCharges'].replace({' ':np.nan}).astype(float)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
##clean the missing value
train_df.fillna(train_df['TotalCharges'].median(),inplace=True)

# %%
train_df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
##replace churn values
train_df['Churn'].replace({'Yes':1,'No':0},inplace=True)

# %%
## Data partition 
X_train_df=train_df.drop('Churn',axis=1)
y_train_df=train_df['Churn']

# %% [markdown]
# # Training Data

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, recall_score,precision_score,f1_score,roc_auc_score
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
##Train test spliting
X_train,X_test,y_train,y_test=train_test_split(X_train_df,y_train_df, test_size=0.2,random_state=42)

# %%
y_train.value_counts()
# Out:
# Churn
# 0    4130
# 1    1504
# Name: count, dtype: int64

# %%
##voting classifier
voting_clf=VotingClassifier(estimators=[
    ('GB',GradientBoostingClassifier()),
    ('AB',AdaBoostClassifier()),
    ('LR',LogisticRegression()),
    ('SVM',SVC())
    ])

# %%
from sklearn.base import BaseEstimator, TransformerMixin
# Custom label encoder wrapper
class PretrainedLabelEncoderWrapper(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoders = {}

    def fit(self, X, y=None):
        for col in X.columns:
            le = LabelEncoder()
            le.fit(X[col])
            self.encoders[col] = le
        return self

    def transform(self, X):
        X_encoded = X.copy()
        for col in X.columns:
            le = self.encoders[col]
            X_encoded[col] = le.transform(X[col])
        return X_encoded

    def inverse_transform(self, X):
        X_decoded = X.copy()
        for col in X.columns:
            le = self.encoders[col]
            X_decoded[col] = le.inverse_transform(X[col])
        return X_decoded

# %%
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer
import pickle
# Define columns
transformed_cols = ['MonthlyCharges', 'TotalCharges', 'tenure']
categorical_features = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
                        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','Contract', 'PaymentMethod']
label_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']


# Define transformers
numeric_transformer = Pipeline([
    ('power', PowerTransformer(method='yeo-johnson'))
])

categorical_transformer = Pipeline([
     ('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
 ])

label_encoder_transformer = Pipeline([
    ('label', PretrainedLabelEncoderWrapper())
])

# Build preprocessor
preprocessor = ColumnTransformer([
    ('num', numeric_transformer, transformed_cols),
      ('cat', categorical_transformer, categorical_features),
     ('labels_cols', label_encoder_transformer, label_cols)
],remainder='passthrough',sparse_threshold=0.0)

#Transform training independent features
X_train_processed = preprocessor.fit_transform(X_train)

# Apply SMOTE to the transformed training set(X_train and y_train) to balance the imbalance class
X_resampled, y_resampled = SMOTE(random_state=42).fit_resample(X_train_processed, y_train)

# Train the voting classifier on the resampled data
voting_clf.fit(X_resampled, y_resampled)

inference_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', voting_clf)
])


inference_pipeline.predict()

#saving the preprocessing model and machine learning model for future prediction
with open("VotingClassifiers.pkl","wb") as filesaved:
    pickle.dump(inference_pipeline,filesaved)

# %%
##churn
# Sample input
user_inputs = {
    'gender': 'Female',
    'SeniorCitizen': 0,
    'Partner': 'No',
    'Dependents': 'No',
    'tenure': 1,
    'PhoneService': 'Yes',
    'MultipleLines': 'No',
    'InternetService': 'Cable',
    'OnlineSecurity': 'No',
    'OnlineBackup': 'No',
    'DeviceProtection': 'No',
    'TechSupport': 'No',
    'StreamingTV': 'No',
    'StreamingMovies': 'No',
    'Contract': 'Month-to-month',
    'PaperlessBilling': 'No',
    'PaymentMethod': 'Bank Withdrawal',
    'MonthlyCharges': 71.35,
    'TotalCharges': 71.35
}

# Make sure it's wrapped in a list
new_df = pd.DataFrame([user_inputs])
new_df
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No           Cable             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month               No
#
#      PaymentMethod  MonthlyCharges  TotalCharges
# 0  Bank Withdrawal           71.35         71.35

# %%
with open("VotingClassifiers.pkl","rb") as loadfile:
    classifier_load=pickle.load(loadfile)

# %%
# Predict
predicts_new_df = classifier_load.predict(new_df)
print("Prediction:", predicts_new_df)
if predicts_new_df==0:
    print("Stayed: Not Churned")
else:
    print("Leave: Churned")
# Out:
# Prediction: [1]
# Leave: Churned
